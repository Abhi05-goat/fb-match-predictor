# %%
import pandas as pd
import os

df = pd.read_csv(rf'C:\Users\asiva\OneDrive\Desktop\Fb Match Predictor\ML\train\train.csv')
print(os.listdir(rf'C:\Users\asiva\OneDrive\Desktop\Fb Match Predictor\ClubElo_Data'))

print(df['home_team'].unique())
# Out:
# ['Atalanta.csv', 'Benevento.csv', 'Bologna.csv', 'Brescia.csv', 'Cagliari.csv', 'Carpi.csv', 'Chievo.csv', 'Como.csv', 'Cremonese.csv', 'Crotone.csv', 'Empoli.csv', 'Fiorentina.csv', 'Frosinone.csv', 'Genoa.csv', 'Inter.csv', 'Juventus.csv', 'Lazio.csv', 'Lecce.csv', 'Milan.csv', 'Monza.csv', 'Napoli.csv', 'Palermo.csv', 'Parma.csv', 'Pescara.csv', 'Pisa.csv', 'Reggiana.csv', 'Roma.csv', 'Salernitana.csv', 'Sampdoria.csv', 'Sassuolo.csv', 'SPAL.csv', 'Spezia.csv', 'Torino.csv', 'Udinese.csv', 'Venezia.csv', 'Verona.csv']
# ['Chievo' 'Roma' 'AC Milan' 'Atalanta' 'Cesena' 'Genoa' 'Palermo'
#  'Sassuolo' 'Torino' 'Udinese' 'Empoli' 'Juventus' 'Inter' 'Fiorentina'
#  'Parma Calcio 1913' 'Cagliari' 'Napoli' 'Sampdoria' 'Lazio' 'Verona'
#  'Frosinone' 'Bologna' 'AC Carpi' 'Pescara' 'Crotone' 'Benevento' 'SPAL'
#  'Lecce' 'Brescia' 'Spezia' 'Salernitana' 'Venezia' 'Monza' 'Cremonese'
#  'Como' 'Pisa']

# %%
import os
import pandas as pd
from pathlib import Path
import numpy as np


Base_Dir = Path(__file__).resolve().parents[1]

home_elo_path = rf'{Base_Dir}/ClubElo_Data/{home_team}.csv'
away_elo_path = rf'{Base_Dir}/ClubElo_Data/{away_team}.csv'

df_home_elo = pd.read_csv(home_elo_path)
df_away_elo = pd.read_csv(away_elo_path)

if 'From' not in df_home_elo.columns or 'Elo' not in df_home_elo.columns:
    raise ValueError(f"Unexpected schema in {home_elo_path}: {df_home_elo.columns.tolist()}")

if 'From' not in df_away_elo.columns or 'Elo' not in df_away_elo.columns:
    raise ValueError(f"Unexpected schema in {away_elo_path}: {df_away_elo.columns.tolist()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       3 from pathlib import Path
#       4 import numpy as np
# ----> 7 Base_Dir = Path(__file__).resolve().parents[1]
#       9 home_elo_path = rf'{Base_Dir}/ClubElo_Data/{home_team}.csv'
#      10 away_elo_path = rf'{Base_Dir}/ClubElo_Data/{away_team}.csv'
#
# NameError: name '__file__' is not defined
